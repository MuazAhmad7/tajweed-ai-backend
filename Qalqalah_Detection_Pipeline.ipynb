# %% [markdown]
# # 🎯 Tajweed AI: Simple Qalqalah Detection Pipeline
#
# A clean, step-by-step guide to building a Qalqalah detection system.
#
# ## 📚 What is Qalqalah?
# Qalqalah (قلقلة) is a Tajweed rule that creates a "bouncing" sound when certain letters (ق ط ب ج د) appear at the end of words. This notebook will teach you how to detect it automatically using machine learning.
#
# ## 🚀 Pipeline Steps
# 1. **📊 Dataset Loading** - Load and explore the data
# 2. **🎵 Audio Visualization** - See what audio looks like
# 3. **🔍 Feature Extraction** - Extract meaningful features from audio
# 4. **🤖 Model Training** - Train a classifier
# 5. **📈 Evaluation** - Test how well our model works
#
# Let's get started! 🎉
